# %%
ckpt_path = Path('~ model_state.pt')
config = (~지정.yaml)
model = CnnEncoder(config.model_params)
model.load_state_dict(torch.load(ckpt_path)['model'])
model.eval()
x = data_loader[0]
embedding = model(x)
